# %%
# %%bash
# pip install pyvo astroquery astropy
# Out:
# Requirement already satisfied: pyvo in /Users/johntron/miniconda3/envs/image-processing/lib/python3.11/site-packages (1.4.2)
# Requirement already satisfied: astropy>=4.1 in /Users/johntron/miniconda3/envs/image-processing/lib/python3.11/site-packages (from pyvo) (5.3.2)
# Requirement already satisfied: requests in /Users/johntron/miniconda3/envs/image-processing/lib/python3.11/site-packages (from pyvo) (2.31.0)
# Requirement already satisfied: numpy>=1.21 in /Users/johntron/miniconda3/envs/image-processing/lib/python3.11/site-packages (from astropy>=4.1->pyvo) (1.25.2)
# Requirement already satisfied: pyerfa>=2.0 in /Users/johntron/miniconda3/envs/image-processing/lib/python3.11/site-packages (from astropy>=4.1->pyvo) (2.0.0.3)
# Requirement already satisfied: PyYAML>=3.13 in /Users/johntron/miniconda3/envs/image-processing/lib/python3.11/site-packages (from astropy>=4.1->pyvo) (6.0)
# Requirement already satisfied: packaging>=19.0 in /Users/johntron/miniconda3/envs/image-processing/lib/python3.11/site-packages (from astropy>=4.1->pyvo) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/johntron/miniconda3/envs/image-processing/lib/python3.11/site-packages (from requests->pyvo) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/johntron/miniconda3/envs/image-processing/lib/python3.11/site-packages (from requests->pyvo) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/johntron/miniconda3/envs/image-processing/lib/python3.11/site-packages (from requests->pyvo) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/johntron/miniconda3/envs/image-processing/lib/python3.11/site-packages (from requests->pyvo) (2023.7.22)

# %%
from astroquery.simbad import Simbad
from astropy.coordinates import Angle
import astropy.units as u

def get_celestial_info(object_name):
    customSimbad = Simbad()
    customSimbad.add_votable_fields('dimensions')

    result = customSimbad.query_object(object_name)

    if result is None:
        return "Object not found."

    # Extract coordinates
    ra = result['RA'].data[0]
    dec = result['DEC'].data[0]

    # Convert to Angle objects for better representation
    ra = Angle(f"{ra} hours")
    dec = Angle(f"{dec} degrees")
    print(result.columns)
    # Extract dimensions (angular size)
    dimensions = result['DIMENSIONS'].data[0]
    if dimensions is not None:
        # Assume the first dimension is the major axis
        major_axis = Angle(dimensions.split('x')[0] + " arcmin")
    else:
        major_axis = None

    return ra, dec, major_axis

# Example usage
object_name = "NGC 7000"
ra, dec, major_axis = get_celestial_info(object_name)

print(f"Object: {object_name}")
print(f"RA: {ra.to_string(u.hour)}")
print(f"DEC: {dec.to_string(u.deg)}")
if major_axis:
    print(f"Major Axis: {major_axis.to_string(u.arcmin)}")
else:
    print("Major Axis: Not available")
# Out:
# <TableColumns names=('MAIN_ID','RA','DEC','RA_PREC','DEC_PREC','COO_ERR_MAJA','COO_ERR_MINA','COO_ERR_ANGLE','COO_QUAL','COO_WAVELENGTH','COO_BIBCODE','GALDIM_MAJAXIS','GALDIM_MINAXIS','GALDIM_ANGLE','GALDIM_QUAL','GALDIM_WAVELENGTH','GALDIM_BIBCODE','SCRIPT_NUMBER_ID')>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 34
#      32 # Example usage
#      33 object_name = "NGC 7000"
# ---> 34 ra, dec, major_axis = get_celestial_info(object_name)
#      36 print(f"Object: {object_name}")
#      37 print(f"RA: {ra.to_string(u.hour)}")
#
# Cell In[13], line 23, in get_celestial_info(object_name)
#      21 print(result.columns)
#      22 # Extract dimensions (angular size)
# ---> 23 dimensions = result['DIMENSIONS'].data[0]
#      24 if dimensions is not None:
#      25     # Assume the first dimension is the major axis
#      26     major_axis = Angle(dimensions.split('x')[0] + " arcmin")
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/astropy/table/table.py:2055, in Table.__getitem__(self, item)
#    2053 def __getitem__(self, item):
#    2054     if isinstance(item, str):
# -> 2055         return self.columns[item]
#    2056     elif isinstance(item, (int, np.integer)):
#    2057         return self.Row(self, item)
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/astropy/table/table.py:264, in TableColumns.__getitem__(self, item)
#     253 """Get items from a TableColumns object.
#     254
#     255 ::
#    (...)
#     261   tc[1:3] # <TableColumns names=('b', 'c')>
#     262 """
#     263 if isinstance(item, str):
# --> 264     return OrderedDict.__getitem__(self, item)
#     265 elif isinstance(item, (int, np.integer)):
#     266     return list(self.values())[item]
#
# KeyError: 'DIMENSIONS'

# %%
import pyvo as vo
from astropy.coordinates import SkyCoord
import astropy.units as u

service = vo.dal.TAPService("http://tapvizier.u-strasbg.fr/TAPVizieR/tap")

def description_and_examples():
    if hasattr(service, 'description'):
        print(service.description)
    if hasattr(service, 'examples'):
        print(service.examples)
        
def find_table_by_keyword(keyword:str):
    for table in service.tables:
        if keyword.lower() in table.description.lower():
            print(table.name, ":", table.description)


def table_names_and_descriptions():
    for table in service.tables:
        print(f"{table.name}: {table.description}")

def table_columns():
    # Print out the available tables and columns
    for table in service.tables:
        print(f"Table name: {table.name}")
        for column in table.columns:
            print(f"  - {column.name}")

def get_celestial_info_with_pyvo(object_name):
    # SQL query to find the object
    query = f"""
    SELECT TOP 1 RAJ2000, DEJ2000, BmajAxis, BminAxis
    FROM "II/246/out"
    WHERE MAIN_ID = '{object_name}'
    """
    query = f"""DESCRIBE TABLE II/246/out"""

    # Execute the query
    result = service.search(query)

    if len(result) == 0:
        return "Object not found."

    print(result)
    # Fetch RA, DEC, and angular size (BmajAxis) from the result
    ra = result['RAJ2000'][0] * u.deg
    dec = result['DEJ2000'][0] * u.deg
    major_axis = result['BmajAxis'][0] * u.arcsec  # Assuming major axis is in arcsec

    # Convert RA, DEC to SkyCoord object for easier manipulation
    coord = SkyCoord(ra, dec, frame='icrs')

    return coord.ra, coord.dec, major_axis

# description_and_examples()
find_table_by_keyword('DSS')
# table_names_and_descriptions()
# table_columns()

# %%
# Example usage
object_name = "M31"
ra, dec, major_axis = get_celestial_info_with_pyvo(object_name)

if ra:
    print(f"Object: {object_name}")
    print(f"RA: {ra.to_string(u.hour)}")
    print(f"DEC: {dec.to_string(u.deg)}")
    print(f"Major Axis: {major_axis.to_string(u.arcmin)}")
else:
    print("Object not found.")
# Out:
# J/A+A/635/A13/table1: Radial velocities and activity indicators ( Faria J.P., Adibekyan V., Amazo-Gomez E.M., Barros S.C.C., Camacho J.D., Demangeon O., Figueira P., Mortier A., Oshagh M., Pepe F., Santos N.C., Gomes da Silva J., Costa Silva A.R., Sousa S.G., Ulmer-Moll S., Viana P.T.P.)
# J/A+A/665/A28/table1: Average ULX spectra ( Kovlakas K., Fragos T., Schaerer D., Mesinger A.)
# J/A+A/674/A48/fgas-esz: Planck-ESZ gas fraction sample ( Wicker R., Douspis M., Salvati L., Aghanim N.)
# J/A+A/651/A79/actions: Sub-the spectroscopic sample for which orbital parameters have been computed ( Bonifacio P., Monaco L., Salvadori S., Caffau E., Spite M., Sbordone L., Spite F., Ludwig H.-G., Di Matteo P., Haywood M., Francois P., Koch-Hansen A.J., Christlieb N.C., Zaggia S.)
# J/A+A/643/A71/ngc6633: Membership analysis and selection for NGC 6633 ( Gutierrez Albarran M.L., Montes D., Gomez Garrido M., et al.)
# J/A+A/645/A84/coronae: Cluster members ( Meingast S., Alves J., Rottensteiner A.)
# J/A+A/636/A33/tablea2: Measured rotational transitions for glutaronitrile observed in the mmW region ( Cabezas C., Bermudez C., Endo Y., Tercero B., Cernicharo J.)
# J/A+A/520/A15/tablea: Summary of parameters for the 6 associations (tables A1-A6 of the paper) ( Messina S., Desidera S., Tutatto M., Lanzafame A.C., Guinan E.F.)
# J/A+A/664/A53/harps03: RV data taken with HARPS spectrograph ( Stalport M., Delisle J.-B., Udry S., Matthews E., Bourrier V., Leleu A.)
# J/A+A/617/A108/list: List of fits files ( Appourchaux T., Boumier P., Leibacher J.W., Corbard T.)
# J/A+A/564/A24/table3: Energies, gJ-values and LS-compositions for levels in Ar XIII ( Ekman J., Jonsson P., Gustafsson S., Hartman H., Gaigalas G., Godefroid M.R., Froese Fischer C.)
# J/A+A/638/A108/v16pwr: Amplitude spectrum of V1636 Ori ( Mackebrandt F., Schuh S., Silvotti R., et al.)
# J/A+A/674/A67/table56: Mass=1.10, Z=0.04237 ( Claret A.)
# J/A+A/556/A118/schmas_i: Photometric time series of the star during its occultation by Jupiter, SCHMAS, ingress ( Christou A.A., Beisker W., Casas R., Schnabel C., Massalle A., Diaz-Martin M.C., Assafin M., Braga-Ribas F., Eppich P., Bath K-L., Tsamis V., Tigani K., Farmakopoulos A., Douvris A., Liakos A., Eberle A., Farago O.)
# J/A+A/638/A76/galah: GALAH DR2 StarHorse ( Queiroz A.B.A., Anders F., Chiappini C., et al.)
# J/A+A/600/A81/tablec2: List of the hydrogen and helium diagnostic lines used in the determination of the stellar and wind parameters of the O-giants, bright giants, and supergiants ( Ramirez-Agudelo O.H., Sana H., de Koter A., et al.)
# J/A+A/603/A43/table1: HARPS radial-velocity measurements of CoRoT-9 (CoRoT 105891283) ( Bonomo A.S., Hebrard G., Raymond S.N., et al.)
# J/A+A/363/1051/colors: Synthetic colors in Johnson, Stroemgren and Geneva photometric systems. ( Zboril M.)
# J/A+A/613/A70/table9: CoRoT 102656190 data from LRA1 run light curve ( Semaan T., Hubert A.M., Zorec J., Gutierrez-Soto J., Fremat Y., Martayan C., Fabregat J., Eggenberger P.)
# J/A+A/509/A17/stars: All the variables discovered in our survey of NGC 6253 and its surrounding field (tables A1-A8 of the paper) ( De Marchi F., Poretti E., Montalto M., Desidera S., Piotto G.)
# J/A+A/426/247/table2: Photometric data (HD 173977 - HD 173663) in Stroemgren filters ( Chapellier E., Mathias P., Garrido R., Le Contel J.-M., Sareyan J.-P., Ribas I., Parrao L., Moya A., Pena J.H., Alvarez M.)
# J/A+A/552/A117/tableb2: Predicted transitions of asymmetric DME-1d ( Richard C., Margules L., Caux E., Kahane C., Ceccarelli C., Guillemin J.C., Motiyenko R.A., Vastel C., Groner P.)
# J/A+A/424/447/table3: Major-axis ionized gas kinematics ( Pizzella A., Corsini E.M., Vega-Beltran J.C., Bertola F.)
# J/A+A/390/39/table2: Results of AIROBICC search from gamma-ray emission from a set of 191 candidate point sources ( Aharonian F., Akhperjanian A., Barrio J.A., et al.)
# J/A+A/657/A30/table1: Catalogue of identified continuum sources ( Tang M., Palau A., Zapata L., Qin S.L.)
# J/A+A/578/A22/pol: Light Curve from Steward, St Petersburg and Crimean (polarization degree) ( Aleksic J., Ansoldi S., Antonelli L.A., et al.)
# J/A+A/587/A6/i05113: Linelist of IRAS 05113+1347 ( De Smedt K., Van Winckel H., Kamath D., Siess L., Goriely S., Karakas A.I., Manick R.)
# J/A+A/551/A104/tablevri: Light curves in the VRi filters ( Ricci D., Elyiv A., Finet F., et al.)
# J/A+A/366/868/table2: Speckle measurements on the 1.52-m telescope ( Docobo J.A., Tamazian V.S., Balega Y.Y., Blanco J., Maximov A.F., Vasyuk V.A.)
# J/A+A/642/A176/table10: *Atomic abundances for Fe, Mg, Ca and Sc ( Theler R., Jablonka P., Lucchesi R., Lardo C., North P., Irwin M., Battaglia G., Hill V., Tolstoy E., Venn K., Helmi A., Kaufer A., Primas F., Shetrone M.)
# J/A+A/490/641/table1: Detected Chandra sources in the direction of NGC 2808 ( Servillat M., Dieball A., Webb N.A., Knigge C., Cornelisse R., Barret D., Long K.S., Shara M.M., Zurek D.R.)
# J/A+A/600/A87/list: Informations on fits images ( Giroletti M., Panessa F., Longinotti A.L., Krongold Y., Guainazzi M., Costantini E., Santos-Lleo M.)
# J/A+A/660/A69/listimg: List of fits images ( Watkins A.E., Salo H., Laurikainen E., et al.)
# J/A+A/618/A20/MOSTa: a_1_,a_2_,a_3_,a_4_ LDCs, PHOENIX models for MOST ( Claret A.)
# J/A+A/438/377/kmac1t: The catalogue KMAC1-CU (192 fields) ( Lazorenko P., Babenko Yu, Karbovsky V., Buromsky M., Denisjuk O., Kasjan S.)
# J/A+A/556/A86/table15: Planar Gravity-darkening coefficients ( Neilson H.R., Lester J.B.)
# J/A+A/613/A70/table16: CoRoT 102766835 data from LRA1 run (69 frequencies) and IR1 run (23 frequencies) light curves ( Semaan T., Hubert A.M., Zorec J., Gutierrez-Soto J., Fremat Y., Martayan C., Fabregat J., Eggenberger P.)
# J/A+A/631/A48/tablem1: VRI Photometric Observations of rho Cas from T2 APT ( van Genderen A.M., Lobel A., Nieuwenhuijzen H., Henry G.W., de Jager C., Blown E., Di Scala G., van Ballegoij E.J.)
# J/A+A/552/A60/smcdsp02: McDonald spectrum at mid-exposure time HJD=2455174.92338 ( Maceroni C., Montalban J., Gandolfi D., Pavlovski K., Rainer M.)
# J/A+A/665/A68/lbpn_prm: List of bolometric luminosity versus N2H+ peak position table names and corresponding physical parameters of the model set ( Murillo N.M., Hsieh T.-H., Walsh C.)
# J/A+A/539/A74/catalog: NGC1893 Chandra X-ray catalog: basic source properties ( Caramazza M., Micela G., Prisinzano L., Sciortino S., Damiani F., Favata F., Stauffer J.R., Vallenari A., Wolk S.J.)
# J/A+A/591/A129/tablea3: V346 Cen du, dv, db, dy relative to HD 101466 from Gimenez et al. (1986A&amp;AS...66...45G) ( Mayer P., Harmanec P., Wolf M., Nemravova J., Prsa A., Fremat Y., Zejda M., Liska J., Jurysek J., Honkova K., Masek M.)
# J/A+A/647/A127/spectrum: C^+^ ion photofragment spectrum ( Guan L., Jiang P., Zhang G., Yin T., Cheng M., Gao H.)
# J/A+A/641/L4/11-05-19: Light curve of May 11, 2019 ( Oosterloo T.A., Vedantham H.K., Kutkin A.M., et al.)
# J/A+A/526/A99/table3: Photometry used for the use of IFRM calibration ( Sousa S.G., Santos N.C., Israelian G., Lovis C., Mayor M., Silva P.B., Udry S.)
# J/A+A/664/A47/c1s2_cds: *Comparison star 2 fluxes (with 22 header lines) ( Kovacs G., Dekany I., Karamiqucham B., Chen G., Zhou G., Rabus M., Kovacs T.)
# J/A+A/601/A96/tablea7: Abundances for NGC 7099 ( Larsen S.S., Brodie J.P., Strader J.)
# J/A+A/567/A55/table7: Stellar parameters of the 208 GIRAFFE members ( Spina L., Randich S., Palla F., et al.)
# J/A+A/654/A135/listsp: List of individual spectra ( Diaz-Garcia S., Lisenfeld U., Perez I., Zurita A., Verley S., Combes F., Espada D., Leon S., Martinez-Badenes V., Sabater J., Verdes-Montenegro L.)
# J/A+A/558/A131/listsp: Spectra initial parameters ( Groh J.H., Meynet G., Georgy C., Ekstrom S.)
# J/A+A/580/A19/table6: Observed and dereddened nebular emission line fluxes from Hen 2-155 and Hen 2-161 (table 6) ( Jones D., Boffin H.M.J., Rodriguez-Gil P., Wesson R., Corradi R.L.M., Miszalski B., Mohamed S.)
# J/A+A/654/A157/tablea5: AT 2013lb optical (UBVRI) light curves ( Cai Y-Z., Pastorello A., Fraser M., et al.)
# J/A+A/520/A89/table27: HIPPARCOS photometry, Perryman et al. (1997, I/239) ( Mayer P., Harmanec P., Wolf M., Bozic H., Slechta M.)
# J/A+A/372/364/table9: ISO FIRBACK Source Catalog for the FIRBACK North 2 Field (FN2) ( Dole H., Gispert R., Lagache G., et al.)
# J/A+A/325/159/table2: Companion magnitude limits for southern M dwarfs within five parsecs ( Leinert C., Henry T., Glindemann A., McCArthy D.W. Jr.)
# J/A+A/483/661/grysicpa: Optical constants for gray 6H-SiC powder, extraordinary ray (table 4) ( Pitman K.M., Hofmeister A. M., Corman A.B., Speck A.K.)
# J/A+A/557/A106/esurf060: Time evolution of surface abundances M=6M_{sun}_ ( Gil-Pons P., Doherty C., Lau H., Campbell S., Suda T., Guilani S., Gutierrez J., Lattanzio J.C.)
# J/A+A/637/A7/spnh2d: PKS1830-211 spectrum of the 470GHz transition of NH_2_D ( Muller S., Roueff E., Black J.H., Gerin M., Guelin M., Menten K.M., Henkel C., Aalto S., Combes F., Martin S., Marti-Vidal I.)
# J/A+A/356/1010/table2e: C-type shock models column densities (nH=10^5^cm-3) ( Wilgenbus D., Cabrit S., Pineau des Forets G., Flower D.)
# J/A+A/620/A82/table2: Physical parameters derived through SED-fitting and X-ray spectral analysis ( Circosta C., Mainieri V., Padovani P., et al.)
# J/A+A/642/A206/s1: Measured frequencies and residuals from the global fit of the data for propynethial ( Margules L., McGuirre B.A., Evans C.J., Motiyenko R.A., Remijan A., Guillemin J.C., Wong A., McNaughton D.)
# J/A+A/564/A119/tablea3: Line list and atomic data ( Morel T., Miglio A., Lagarde N., Montalban J., Rainer M., Poretti E., Eggenberger P., Hekker S., Kallinger T., Mosser B., Valentini M., Carrier F., Hareter M., Mantegazza L.)
# J/A+A/673/A155/gaiarvs: Gaia RVS DR3 StarHorse (corrected version) ( Queiroz A.B.A., Anders F., Chiappini C., et al.)
# J/A+A/642/A108/bband: B-band photometry of the central star of PN G283.7-05.1 ( Jones D., Boffin M.M.J., Hibbert J., Steinmetz T., Wesson R., Hillwig T.C., Sowicka P., Corradi R.L.M., Garcia-Rojas J., Rodriguez-Gil P., Munday J.)
# J/A+A/357/871/stars: single-period RR Lyrae stars observed in fields 1 (SAG) and 2 (DUO) ( Cseresnjes P., Alard C., Guibert J.)
# J/A+A/460/959/table1: Target levels of Ni XIX, their threshold energies and lifetimes ({tau}) ( Aggarwal K.M., Keenan F.P.)
# J/A+A/608/A33/ns2000: Neutralization rate coefficients at T=2000K for single charge ( Belyaev A.K., Yakovleva S.A)
# J/A+A/672/A161/ngc2121: NGC 2121 photometry ( Milone A.P., Cordoni, G., et al.)
# J/A+A/586/A116/tco_f: Measured quantities for the Three College Observatory data set ( Jerabkova T., Korcakova D., Miroshnichenko A., Danford S., Zharikov S.V., Kricek R., Zasche P., Votruba V., Slechta M., Skoda P., Janik J.)
# J/A+A/610/L12/time_p04: Pointing 04 times of mid-exposure of each spectrum ( Deeg H.J., Alonso R., Nespral D., Boyajian T.)
# J/A+A/619/A1/apt55cnc: Photometry of 55 Cnc ( Bourrier V., Dumusque X., Dorn C., Henry G.W., Astudillo-Defru N., Rey J., Benneke B., Hebrard G., Lovis C., Demory B.O., Moutou C., Ehrenreich D.)
# J/A+A/619/A48/catalog: GOODS-N VLBI detections and radio properties (corrected version) ( Radcliffe J.F., Garrett M.A., Muxlow T.W.B., Beswick R.J., Barthel P.D., Deller A.T., Keimpema A., Campbell R.M., Wrigley N.)
# J/A+A/453/1003/refs: References ( Thompson M.A., Hatchell J., Walsh A.J., Macdonald G.H., Millar T.J.)
# J/A+A/402/113/table4: List of 26 Cepheids observed in our study with their characteristic parameters ( Joshi Y.C., Pandey A.K., Narashimha D., Sagar R., Giraud-Heraud Y.)
# J/A+A/623/A105/table4: Extended HII regions in the Urumqi {lambda}6cm survey ( Gao X.Y., Reich P., Hou L.G., Reich W., Han J.L.)
# J/A+A/608/A33/rt5000: BaH+ model rate coefficients at T=5000K ( Belyaev A.K., Yakovleva S.A)
# J/A+A/658/A109/skm-cobs: Object table contains a single entry per SSO, with its average colors ( Sergeyev A.V., Carry B., Onken C.A., Devillepoix H.A.R., Wolf C., Chang S.W.)
# J/A+A/321/293/table1b: *Dissociation on impact parameters ( Schilke P., Walmsley C.M., Pineau des Forets G., Flower D.R.)
# J/A+A/563/A13/catalog: Catalog of horizontal- branch stars in M22 ( Gratton R.G., Lucatello S., Sollima A., Carretta E., Bragaglia A., Momany Y., D'Orazi V., Cassisi S., Salaris M.)
# J/A+A/444/79/table8: X-ray catalogue ( Mateos S., Barcons X., Carrera F.J., Ceballos M.T., Hasinger G., Lehmann I., Fabian A.C., Streblyanska A.)
# J/A+A/575/A55/j1505p03: The radio light curves of J1505+0326 ( Angelakis E., Fuhrmann L., Marchili N., Foschini L., Myserlis I., Karamanavis V., Komossa S., Blinov D., Krichbaum T.P., Sievers A., Ungerechts H., Zensus J.A.)
# J/A+A/616/A37/table23: Perihelion parameters for all objects with a median perihelion distance below 10pc (table 2) and additional information on the objects (table 3), in order of increasing median perihelion distance ( Bailer-Jones C.A.L., Rybizki J., Andrae R., Fouesneau M.)
# J/A+A/475/775/table1: The catalogue of hard X-ray sources ( Krivonos R., Revnivtsev M., Lutovinov A., Sazonov S., Churazov E., Sunyaev R.)
# J/A+A/466/481/galaxies: Galaxies in the search area,  with cross-identications ( Schroeder A.C., Mamon G.A., Kraan-Korteweg R.C., Woudt P.A.)
# J/A+A/559/A36/table2: Radial velocity measurements of WASP-65 ( Gomez Maqueo Chew Y., Faedi F., Pollacco D., et al.)
# J/A+A/606/A53/hdo27nov: Retrieved H_2_O disk-averaged retrievals obtained for 2011-11-27 set of observation ( Piccialli A., Moreno R., Encrenaz T., Fouchet T., Lellouch E., Widemann T.)
# J/A+A/478/701/table1: The DLA absorption sample of quasars ( Vladilo G., Prochaska J., Wolfe A.M.)
# J/A+A/523/A17/tablea4: List of all the lines, their associated parameters and their measured equivalent width for our 81 stars ( Letarte B., Hill V., Tolstoy E., Jablonka P., Shetrone M., Venn K.A., Spite M., Irwin M.J., Battaglia G., Helmi A., Primas F., Francois P., Kaufer A., Szeifert T., Arimoto N., Sadakane K.)
# J/A+A/631/A169/lcr150: HAT-P-1b wavelength dependent light curves (R150) ( Todorov K.O., Desert J.-M., Huitson C.M., Bean J.L., Panwar V., de Matos F., Stevenson K.B., Fortney J.J., Bergmann M.)
# J/A+A/585/A36/hdo: Line profile of the HDO transition ( Quenard D., Taquet V., Vastel C., Caselli P., Ceccarelli C.)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 51
#      48     return coord.ra, coord.dec, major_axis
#      50 # description_and_examples()
# ---> 51 table_names_and_descriptions()
#      52 # table_columns()
#      53
#      54 # Example usage
#      55 object_name = "M31"
#
# Cell In[15], line 14, in table_names_and_descriptions()
#      13 def table_names_and_descriptions():
# ---> 14     for table in service.tables:
#      15         print(f"{table.name}: {table.description}")
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/pyvo/dal/vosi.py:151, in VOSITables.__iter__(self)
#     149 def __iter__(self):
#     150     for tablename in self.keys():
# --> 151         yield self._get_table(tablename)
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/pyvo/dal/vosi.py:161, in VOSITables._get_table(self, name)
#     159 if not table.columns and not table.foreignkeys:
#     160     tables_url = '{}/{}'.format(self._endpoint_url, name)
# --> 161     response = self._get_table_file(tables_url)
#     163     try:
#     164         response.raise_for_status()
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/pyvo/utils/decorators.py:19, in response_decode_content.<locals>.wrapper(*args, **kwargs)
#      17 @wraps(func)
#      18 def wrapper(*args, **kwargs):
# ---> 19     response = func(*args, **kwargs)
#      20     response.raw.read = partial(response.raw.read, decode_content=True)
#      21     return response
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/pyvo/dal/vosi.py:175, in VOSITables._get_table_file(self, tables_url)
#     173 @response_decode_content
#     174 def _get_table_file(self, tables_url):
# --> 175     return self._session.get(tables_url, stream=True)
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/image-processing/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:
